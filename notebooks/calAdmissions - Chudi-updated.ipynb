# %%
import pandas as pd
fresh = pd.read_csv("Freshmen.csv")
fresh
# Out:
#                                Calculation1          Campus           City  \
# 0            F BRAVO MEDICAL MAGNET HS51719       Riverside    Los Angeles
# 1                   ARAGON HIGH SCHOOL53163   Santa Barbara      San Mateo
# 2                 ETIWANDA HIGH SCHOOL50888       San Diego       Etiwanda
# 3                   UPLAND HIGH SCHOOL53586          Merced         Upland
# 4              MORNINGSIDE HIGH SCHOOL51262     Los Angeles      Inglewood
# 5                 SAN JOSE HIGH SCHOOL53098           Davis       San Jose
# 6           MIDDLE COLLEGE HIGH SCHOOL53204     Los Angeles      San Pablo
# 7               BROOKWOOD HIGH SCHOOL112754  Universitywide     Snellville
# 8                  CHAFFEY HIGH SCHOOL52275  Universitywide        Ontario
# 9            VICTOR VALLEY HIGH SCHOOL53660  Universitywide    Victorville
# 10      WINSTON CHURCHILL HIGH SCHOOL446273  Universitywide    San Antonio
# ...

# %%
from matplotlib import pyplot as plt
import matplotlib

# %%
gpa = pd.read_csv("GPA.csv")
gpa
# Out:
#                                 Calculation1          Campus             City  \
# 0       GERMAN SWISS INTERNATIONAL SCH670905        Berkeley              NaN
# 1                  AQUINAS HIGH SCHOOL052772       Riverside   San Bernardino
# 2           DESIGN SCIENCE HIGH SCHOOL054003     Los Angeles           Fresno
# 3         BLOOMFIELD HILLS HIGH SCHOOL232447  Universitywide   Bloomfield Twp
# 4               A B MILLER HIGH SCHOOL050944   Santa Barbara          Fontana
# 5                  WAYZATA HIGH SCHOOL242650           Davis         Plymouth
# 6        BISHOP MONTGOMERY HIGH SCHOOL053512          Merced         Torrance
# 7           JOHN A ROWLAND HIGH SCHOOL052696      Santa Cruz  Rowland Heights
# 8         JAMES A GARFIELD HIGH SCHOOL051635        Berkeley      Los Angeles
# 9                 MONTEREY HIGH SCHOOL052050  Universitywide         Monterey
# 10                   CAJON HIGH SCHOOL052773       San Diego   San Bernardino
# ...

# %%
trans = pd.read_csv("Transfers.csv")
trans
# Out:
#                              Calculation1          Campus             City  \
# 0                       BUTTE COLLEGE4226           Davis         Oroville
# 1             IMPERIAL VALLEY COLLEGE4358       Riverside         Imperial
# 2               ALLAN HANCOCK COLLEGE4002  Universitywide      Santa Maria
# 3              AMERICAN RIVER COLLEGE4004        Berkeley       Sacramento
# 4                      CUESTA COLLEGE4101   Santa Barbara  San Luis Obispo
# 5               COLLEGE OF THE DESERT4085       Riverside      Palm Desert
# 6               PASADENA CITY COLLEGE4604       Riverside         Pasadena
# 7                 GREEN RIVER COLLEGE4337     Los Angeles           Auburn
# 8                       BUTTE COLLEGE4226   Santa Barbara         Oroville
# 9               ALLAN HANCOCK COLLEGE4002  Universitywide      Santa Maria
# 10                NAPA VALLEY COLLEGE4530      Santa Cruz             Napa
# ...

# %%
#How is the ratio of admitted students to applied students differ amongst different ethnicities at UC Berkeley Over various Semesters?
#--Data Frames only cover Fall 2017--

# %%
trans = trans.rename(columns = {'adm (SUM)':'admitted', 'app (SUM)':'applied', 'enr (SUM)':'enrolled', 'Uad Uc Ethn 6 Cat':'Ethnicity'})

# %%
fresh = fresh.rename(columns = {'adm (SUM)':'admitted', 'app (SUM)':'applied', 'enr (SUM)':'enrolled', 'Uad Uc Ethn 6 Cat':'Ethnicity'})

# %%
gpa = gpa.rename(columns = {'adm (SUM)':'admitted_gpa', 'app (SUM)':'applied_gpa', 'enr (SUM)':'enrolled_gpa'})

# %%
trans_2017 = trans[trans["Fall Term"] == 2017]

# %%
fresh_2017 = fresh[fresh["Fall Term"] == 2017]

# %%
fresh_2017
# Out:
#                                 Calculation1          Campus             City  \
# 32                LANCASTER HIGH SCHOOL51412        Berkeley        Lancaster
# 51               POINT LOMA HIGH SCHOOL52870          Irvine        San Diego
# 64         FLOYD B BUCHANAN HIGH SCHOOL50618          Merced           Clovis
# 77              CLOVIS WEST HIGH SCHOOL50982  Universitywide           Fresno
# 85               CENTENNIAL HIGH SCHOOL50650          Irvine          Compton
# 113                 BENICIA HIGH SCHOOL50280      Santa Cruz          Benicia
# 131      ACADEMY OF SCIENTIFIC EXPLORAT54563          Merced     San Fernando
# 138      ALLIANCE COLLINS FAMILY COLRDY54118           Davis  Huntington Park
# 158              RIVERSIDE STEM ACADEMY54784          Irvine        Riverside
# 164           SONOMA VALLEY HIGH SCHOOL53390           Davis           Sonoma
# 185                  DUBLIN HIGH SCHOOL50784   Santa Barbara           Dublin
# ...

# %%
#number of freshmen that applied to UC Berkeley based on ethnicity in Fall 2017
fresh_applied_by_campus = fresh_2017.groupby(['Campus','Ethnicity']).applied.agg(['sum']).head(8)
fresh_applied_by_campus #.drop(index='All', level=1)
# Out:
#                              sum
# Campus   Ethnicity
# Berkeley African American   1395
#          All               58412
#          American Indian       5
#          Asian             19813
#          Domestic Unknown    675
#          Hispanic/ Latino  10343
#          Inter- national    3791
#          White             12562

# %%
#bar graph on number of freshmen that applied to UC Berkeley based on ethnicity in Fall 2017
fresh_applied_by_campus.plot.bar()
matplotlib.style.use('seaborn-deep')

# %%
#number of freshmen admitted to UC Berkeley based on ethnicity in Fall 2017
fresh_admitted_by_campus = fresh_2017.groupby(['Campus','Ethnicity']).admitted.agg(['sum']).head(8)
fresh_admitted_by_campus
# Out:
#                                sum
# Campus   Ethnicity
# Berkeley African American     39.0
#          All               10616.0
#          American Indian       0.0
#          Asian              3973.0
#          Domestic Unknown     85.0
#          Hispanic/ Latino    637.0
#          Inter- national     211.0
#          White              2013.0

# %%
#bar graph on number of freshmen admitted to UC Berkeley based on ethnicity in Fall 2017
fresh_admitted_by_campus.plot.bar()
matplotlib.style.use('seaborn-deep')

# %%
#number of transfer students that applied to UC Berkeley organised by ethnicity in Fall 2017
trans_applied_by_campus = trans_2017.groupby(['Campus','Ethnicity']).applied.agg(['sum']).head(8)
trans_applied_by_campus #.drop(index='All', level=1)
# Out:
#                              sum
# Campus   Ethnicity
# Berkeley African American   1502
#          All               33796
#          American Indian      20
#          Asian              8728
#          Domestic Unknown    166
#          Hispanic/ Latino   7162
#          Inter- national    5584
#          White              8756

# %%
#bar graph on number of transfer students that applied to UC Berkeley organised by ethnicity in Fall 2017
trans_applied_by_campus.plot.bar()
matplotlib.style.use('seaborn-deep')

# %%
#number of transfer students admitted to UC Berkeley, organised by ethnicity in Fall 2017
trans_admitted_by_campus = trans_2017.groupby(['Campus','Ethnicity']).admitted.agg(['sum']).head(8)
trans_admitted_by_campus #.drop(index='All', level=1)
# Out:
#                               sum
# Campus   Ethnicity
# Berkeley African American   266.0
#          All               8390.0
#          American Indian      0.0
#          Asian             2092.0
#          Domestic Unknown    14.0
#          Hispanic/ Latino  1626.0
#          Inter- national   1186.0
#          White             2476.0

# %%
    #bar graph on number of transfer students admitted to UC Berkeley, organised by ethnicity in Fall 2017
trans_admitted_by_campus.plot.bar()
matplotlib.style.use('seaborn-deep')
