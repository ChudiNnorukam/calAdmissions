# %%
from __future__ import print_function, division
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
gpa = pd.read_csv("GPA.csv")

# %%
gpa.head()
# Out:
#                            Calculation1          Campus            City  \
# 0  GERMAN SWISS INTERNATIONAL SCH670905        Berkeley             NaN
# 1             AQUINAS HIGH SCHOOL052772       Riverside  San Bernardino
# 2      DESIGN SCIENCE HIGH SCHOOL054003     Los Angeles          Fresno
# 3    BLOOMFIELD HILLS HIGH SCHOOL232447  Universitywide  Bloomfield Twp
# 4          A B MILLER HIGH SCHOOL050944   Santa Barbara         Fontana
#
#   County/State/Country  Fall Term     Level                          School  \
# 0            HONG KONG       2012  Freshman  GERMAN SWISS INTERNATIONAL SCH
# 1       San Bernardino       1995  Freshman             AQUINAS HIGH SCHOOL
# 2               Fresno       2012  Freshman      DESIGN SCIENCE HIGH SCHOOL
# 3             Michigan       2015  Freshman    BLOOMFIELD HILLS HIGH SCHOOL
# 4       San Bernardino       1998  Freshman          A B MILLER HIGH SCHOOL
#
#    Adm GPA (SUM)  App GPA (SUM)  Enrl GPA (SUM)
# ...

# %%
len(gpa)
# Out:
# 333312

# %%
gpa_1 = gpa.drop_duplicates(subset='Fall Term', keep='first')
gpa_1.head()
# Out:
#                            Calculation1          Campus            City  \
# 0  GERMAN SWISS INTERNATIONAL SCH670905        Berkeley             NaN
# 1             AQUINAS HIGH SCHOOL052772       Riverside  San Bernardino
# 3    BLOOMFIELD HILLS HIGH SCHOOL232447  Universitywide  Bloomfield Twp
# 4          A B MILLER HIGH SCHOOL050944   Santa Barbara         Fontana
# 5             WAYZATA HIGH SCHOOL242650           Davis        Plymouth
#
#   County/State/Country  Fall Term     Level                          School  \
# 0            HONG KONG       2012  Freshman  GERMAN SWISS INTERNATIONAL SCH
# 1       San Bernardino       1995  Freshman             AQUINAS HIGH SCHOOL
# 3             Michigan       2015  Freshman    BLOOMFIELD HILLS HIGH SCHOOL
# 4       San Bernardino       1998  Freshman          A B MILLER HIGH SCHOOL
# 5            Minnesota       2013  Freshman             WAYZATA HIGH SCHOOL
#
#    Adm GPA (SUM)  App GPA (SUM)  Enrl GPA (SUM)
# ...

# %%
len(gpa_1)
# Out:
# 24

# %%
transfers = pd.read_csv("Transfers.csv")

# %%
transfers.head()
# Out:
#                   Calculation1          Campus             City  \
# 0            BUTTE COLLEGE4226           Davis         Oroville
# 1  IMPERIAL VALLEY COLLEGE4358       Riverside         Imperial
# 2    ALLAN HANCOCK COLLEGE4002  Universitywide      Santa Maria
# 3   AMERICAN RIVER COLLEGE4004        Berkeley       Sacramento
# 4           CUESTA COLLEGE4101   Santa Barbara  San Luis Obispo
#
#   County/State/ Territory  Fall Term                   School  \
# 0                   Butte       2007            BUTTE COLLEGE
# 1                Imperial       2008  IMPERIAL VALLEY COLLEGE
# 2           Santa Barbara       2012    ALLAN HANCOCK COLLEGE
# 3              Sacramento       1996   AMERICAN RIVER COLLEGE
# 4         San Luis Obispo       2013           CUESTA COLLEGE
#
#                             Sch Src TR Uad Uc Ethn 6 Cat  adm (SUM)  \
# 0  California Community Colleges (CCC)             White       22.0
# ...

# %%
len(transfers)
# Out:
# 103965

# %%
transfers_1 = transfers.drop_duplicates(subset='Fall Term', keep='first')
transfers_1.head()
# Out:
#                   Calculation1          Campus             City  \
# 0            BUTTE COLLEGE4226           Davis         Oroville
# 1  IMPERIAL VALLEY COLLEGE4358       Riverside         Imperial
# 2    ALLAN HANCOCK COLLEGE4002  Universitywide      Santa Maria
# 3   AMERICAN RIVER COLLEGE4004        Berkeley       Sacramento
# 4           CUESTA COLLEGE4101   Santa Barbara  San Luis Obispo
#
#   County/State/ Territory  Fall Term                   School  \
# 0                   Butte       2007            BUTTE COLLEGE
# 1                Imperial       2008  IMPERIAL VALLEY COLLEGE
# 2           Santa Barbara       2012    ALLAN HANCOCK COLLEGE
# 3              Sacramento       1996   AMERICAN RIVER COLLEGE
# 4         San Luis Obispo       2013           CUESTA COLLEGE
#
#                             Sch Src TR Uad Uc Ethn 6 Cat  adm (SUM)  \
# 0  California Community Colleges (CCC)             White       22.0
# ...

# %%
len(transfers_1)
# Out:
# 24

# %%
freshmen = pd.read_csv("Freshmen.csv")

# %%
freshmen.head()
# Out:
#                      Calculation1         Campus         City  \
# 0  F BRAVO MEDICAL MAGNET HS51719      Riverside  Los Angeles
# 1         ARAGON HIGH SCHOOL53163  Santa Barbara    San Mateo
# 2       ETIWANDA HIGH SCHOOL50888      San Diego     Etiwanda
# 3         UPLAND HIGH SCHOOL53586         Merced       Upland
# 4    MORNINGSIDE HIGH SCHOOL51262    Los Angeles    Inglewood
#
#   County/State/ Territory  Fall Term                     School  \
# 0             Los Angeles       2008  F BRAVO MEDICAL MAGNET HS
# 1               San Mateo       2012         ARAGON HIGH SCHOOL
# 2          San Bernardino       2012       ETIWANDA HIGH SCHOOL
# 3          San Bernardino       2005         UPLAND HIGH SCHOOL
# 4             Los Angeles       2006    MORNINGSIDE HIGH SCHOOL
#
#                       Sch Src FR Uad Uc Ethn 6 Cat  adm (SUM)  app (SUM)  \
# 0  California Public High School  Hispanic/ Latino       39.0         50
# ...

# %%
len(freshmen)
# Out:
# 587501

# %%
freshmen_1 = freshmen.drop_duplicates(subset='Fall Term', keep='first')
freshmen_1.head()
# Out:
#                       Calculation1         Campus         City  \
# 0   F BRAVO MEDICAL MAGNET HS51719      Riverside  Los Angeles
# 1          ARAGON HIGH SCHOOL53163  Santa Barbara    San Mateo
# 3          UPLAND HIGH SCHOOL53586         Merced       Upland
# 4     MORNINGSIDE HIGH SCHOOL51262    Los Angeles    Inglewood
# 6  MIDDLE COLLEGE HIGH SCHOOL53204    Los Angeles    San Pablo
#
#   County/State/ Territory  Fall Term                      School  \
# 0             Los Angeles       2008   F BRAVO MEDICAL MAGNET HS
# 1               San Mateo       2012          ARAGON HIGH SCHOOL
# 3          San Bernardino       2005          UPLAND HIGH SCHOOL
# 4             Los Angeles       2006     MORNINGSIDE HIGH SCHOOL
# 6            Contra Costa       2003  MIDDLE COLLEGE HIGH SCHOOL
#
#                       Sch Src FR Uad Uc Ethn 6 Cat  adm (SUM)  app (SUM)  \
# 0  California Public High School  Hispanic/ Latino       39.0         50
# ...

# %%
len(freshmen_1)
# Out:
# 24

# %%
freshmen.sort_values('adm (SUM)', ascending=False).head()
# Out:
#                              Calculation1          Campus City  \
# 39896   INSTITUTION IN THE FAR EAST989345  Universitywide  NaN
# 20557   INSTITUTION IN THE FAR EAST989345  Universitywide  NaN
# 581037  INSTITUTION IN THE FAR EAST989345          Irvine  NaN
# 581045  INSTITUTION IN THE FAR EAST989345          Irvine  NaN
# 417743  INSTITUTION IN THE FAR EAST989345  Universitywide  NaN
#
#         County/State/ Territory  Fall Term                       School  \
# 39896   CHINA, PEOPLES REPUBLIC       2015  INSTITUTION IN THE FAR EAST
# 20557   CHINA, PEOPLES REPUBLIC       2015  INSTITUTION IN THE FAR EAST
# 581037  CHINA, PEOPLES REPUBLIC       2015  INSTITUTION IN THE FAR EAST
# 581045  CHINA, PEOPLES REPUBLIC       2015  INSTITUTION IN THE FAR EAST
# 417743  CHINA, PEOPLES REPUBLIC       2014  INSTITUTION IN THE FAR EAST
#
#                  Sch Src FR Uad Uc Ethn 6 Cat  adm (SUM)  app (SUM)  enr (SUM)
# ...

# %%
freshmen.sort_values('adm (SUM)').head()
# Out:
#                              Calculation1          Campus          City  \
# 180511    CENTRAL VALLEY HIGH SCHOOL53988        Berkeley         Ceres
# 576035            WILTON HIGH SCHOOL70938  Universitywide        Wilton
# 166274    JAMES C ENOCHS HIGH SCHOOL54043       San Diego       Modesto
# 166273   CRYSTAL SPRINGS UPLANDS SCH51173     Los Angeles  Hillsborough
# 522345  FOREST LAKE CHRISTIAN SCHOOL50173           Davis        Auburn
#
#        County/State/ Territory  Fall Term                        School  \
# 180511              Stanislaus       2015    CENTRAL VALLEY HIGH SCHOOL
# 576035             Connecticut       2015            WILTON HIGH SCHOOL
# 166274              Stanislaus       2017    JAMES C ENOCHS HIGH SCHOOL
# 166273               San Mateo       1997   CRYSTAL SPRINGS UPLANDS SCH
# 522345                  Placer       2004  FOREST LAKE CHRISTIAN SCHOOL
#
#                             Sch Src FR Uad Uc Ethn 6 Cat  adm (SUM)  \
# ...

# %%
transfers.sort_values('adm (SUM)', ascending=False).head()
# Out:
#                    Calculation1          Campus          City  \
# 85454  SANTA MONICA COLLEGE4691  Universitywide  Santa Monica
# 85453  SANTA MONICA COLLEGE4691  Universitywide  Santa Monica
# 85450  SANTA MONICA COLLEGE4691  Universitywide  Santa Monica
# 58598  SANTA MONICA COLLEGE4691  Universitywide  Santa Monica
# 6966   SANTA MONICA COLLEGE4691  Universitywide  Santa Monica
#
#       County/State/ Territory  Fall Term                School  \
# 85454             Los Angeles       2017  SANTA MONICA COLLEGE
# 85453             Los Angeles       2016  SANTA MONICA COLLEGE
# 85450             Los Angeles       2010  SANTA MONICA COLLEGE
# 58598             Los Angeles       2009  SANTA MONICA COLLEGE
# 6966              Los Angeles       2015  SANTA MONICA COLLEGE
#
#                                 Sch Src TR Uad Uc Ethn 6 Cat  adm (SUM)  \
# 85454  California Community Colleges (CCC)               All     3328.0
# ...

# %%
transfers.sort_values('Fall Term').head()
# Out:
#                         Calculation1     Campus           City  \
# 42873          RIO HONDO COLLEGE4663     Irvine       Whittier
# 24836  SAN JOAQUIN DELTA COLLEGE4706      Davis       Stockton
# 48709           MOORPARK COLLEGE4512   Berkeley       Moorpark
# 98296           UC SANTA BARBARA4835   Berkeley  Santa Barbara
# 84292          SANTA ANA COLLEGE4689  San Diego      Santa Ana
#
#       County/State/ Territory  Fall Term                     School  \
# 42873             Los Angeles       1994          RIO HONDO COLLEGE
# 24836             San Joaquin       1994  SAN JOAQUIN DELTA COLLEGE
# 48709                 Ventura       1994           MOORPARK COLLEGE
# 98296           Santa Barbara       1994           UC SANTA BARBARA
# 84292                  Orange       1994          SANTA ANA COLLEGE
#
#                                 Sch Src TR Uad Uc Ethn 6 Cat  adm (SUM)  \
# 42873  California Community Colleges (CCC)               All       56.0
# ...

# %%
print(list(set(freshmen.loc[:,'Sch Src FR'])))
# Out:
# ['Foreign Institution', 'California Private High School', 'California Public High School', 'Non-CA Domestic High School']

# %%
print(list(set(transfers.loc[:,'Sch Src TR'])))
# Out:
# ['Other (not to include unknown)', 'Foreign Institution', 'Non-California Institution (US)', 'California Community Colleges (CCC)', 'University of California (UC)', 'CA Private Institutions', 'California State Universities (CSU)']

# %%
freshmen_by_campus = freshmen.groupby(["Campus"]).count().sort_values(by="adm (SUM)")
freshmen_by_campus
# Out:
#                 Calculation1    City  County/State/ Territory  Fall Term  \
# Campus
# Merced                 14817   14815                    14817      14817
# Berkeley               64776   61652                    64776      64776
# Riverside              39854   39700                    39854      39854
# Santa Cruz             43743   43339                    43743      43743
# Los Angeles            70722   67674                    70722      70722
# Irvine                 53796   52423                    53796      53796
# San Diego              59838   57716                    59838      59838
# Davis                  55516   54178                    55516      55516
# Santa Barbara          60023   59102                    60023      60023
# Universitywide        124416  117509                   124416     124416
#
#                 School  Sch Src FR  Uad Uc Ethn 6 Cat  adm (SUM)  app (SUM)  \
# Campus
# ...

# %%
prop_fresh = freshmen_by_campus['adm (SUM)'] / freshmen_by_campus['app (SUM)']
prop_fresh
# Out:
# Campus
# Merced            0.963893
# Berkeley          0.569177
# Riverside         0.958172
# Santa Cruz        0.930595
# Los Angeles       0.606403
# Irvine            0.864748
# San Diego         0.792373
# Davis             0.866633
# Santa Barbara     0.864419
# Universitywide    0.936833
# dtype: float64

# %%
gpa.groupby(["Campus"]).mean().sort_values(by="Adm GPA (SUM)")
# Out:
#                   Fall Term  Adm GPA (SUM)  App GPA (SUM)  Enrl GPA (SUM)
# Campus
# Merced          2011.006270       3.547102       3.423051        3.477554
# Riverside       2007.188794       3.590100       3.446614        3.402879
# Santa Cruz      2007.320350       3.675936       3.502721        3.478790
# Universitywide  2007.916748       3.795111       3.673213        3.775328
# Santa Barbara   2007.561768       3.841144       3.595907        3.658178
# Irvine          2007.729670       3.882455       3.605246        3.723817
# Davis           2007.580543       3.887820       3.647649        3.736864
# San Diego       2007.802723       4.009340       3.702803        3.864250
# Los Angeles     2008.139680       4.048286       3.736466        3.947703
# Berkeley        2007.957256       4.077569       3.799817        3.981637

# %%
gpa.sort_values(by="Adm GPA (SUM)", ascending=False).head()
# Out:
#                                Calculation1          Campus           City  \
# 177727   SAINT STEPHENS EPISCOPAL SCH440315       San Diego         Austin
# 34913   FLINTRIDGE PREPARATORY SCHOOL052375        Berkeley      La Canada
# 131316  FLINTRIDGE PREPARATORY SCHOOL052375        Berkeley      La Canada
# 24660          CENTENNIAL HIGH SCHOOL210509  Universitywide  Ellicott City
# 41734            LAGUNA BLANCA SCHOOL053255        Berkeley  Santa Barbara
#
#        County/State/Country  Fall Term     Level  \
# 177727                Texas       2008  Freshman
# 34913           Los Angeles       2006  Freshman
# 131316          Los Angeles       2008  Freshman
# 24660              Maryland       2005  Freshman
# 41734         Santa Barbara       2008  Freshman
#
#                                School  Adm GPA (SUM)  App GPA (SUM)  \
# 177727   SAINT STEPHENS EPISCOPAL SCH       4.504000       4.188333
# 34913   FLINTRIDGE PREPARATORY SCHOOL       4.495000       4.022143
# ...

# %%
transfers_by_campus = transfers.groupby(["Campus"]).sum().sort_values(by="adm (SUM)")
transfers_by_campus
# Out:
#                 Fall Term  adm (SUM)  app (SUM)  enr (SUM)
# Campus
# Merced            4511056    54951.0      84612     3566.0
# Berkeley         23996191   257507.0     963135   166178.0
# Santa Cruz       16916458   313405.0     478687    74356.0
# Riverside        15581440   343617.0     481163    75933.0
# Los Angeles      25420226   411989.0    1221547   242726.0
# Irvine           19031343   474180.0     857393   129205.0
# Santa Barbara    20376253   487604.0     814211   120995.0
# San Diego        19674980   497238.0     873491   153971.0
# Davis            20343844   498333.0     777050   185830.0
# Universitywide   42778956  1747249.0    2446792  1271457.0

# %%
prop_transfers = transfers_by_campus['adm (SUM)'] / transfers_by_campus['app (SUM)']
prop_transfers
# Out:
# Campus
# Merced            0.649447
# Berkeley          0.267363
# Santa Cruz        0.654718
# Riverside         0.714138
# Los Angeles       0.337268
# Irvine            0.553049
# Santa Barbara     0.598867
# San Diego         0.569254
# Davis             0.641314
# Universitywide    0.714098
# dtype: float64

# %%
#How many high schools are included in all three of the datasets?
len(set(gpa['Calculation1']) & set(transfers['Calculation1']) & set(freshmen['Calculation1']))
# Out:
# 34

# %%
#How many high schools are included in only 2 of the datasets? (gpa & transfers)
len(set(gpa['Calculation1']) & set(transfers['Calculation1']))
# Out:
# 56

# %%
#How many high schools are included in only 2 of the datasets? (gpa & freshmen)
len(set(gpa['Calculation1']) & set(freshmen['Calculation1']))
# Out:
# 2903

# %%
#How many high schools are included in only 2 of the datasets? (freshmen & transfers)
len(set(transfers['Calculation1']) & set(freshmen['Calculation1']))
# Out:
# 35
